# %%
# !pip install crewai==0.80.0
# !pip install langchain-groq==0.2.1
# !pip install fpdf
# Out:
# Requirement already satisfied: crewai==0.80.0 in /usr/local/lib/python3.12/dist-packages (0.80.0)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (5.7.0)
# Requirement already satisfied: chromadb>=0.4.24 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.5.9)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (8.4.1)
# Requirement already satisfied: crewai-tools>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (0.76.0)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.15.3)
# Requirement already satisfied: json-repair>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (0.61.0)
# Requirement already satisfied: jsonref>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.1.0)
# Requirement already satisfied: langchain>=0.2.16 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.3.6)
# Requirement already satisfied: litellm>=1.44.22 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.89.3)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (2.41.0)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.38.0)
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (2.12.3)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.2.2)
# Requirement already satisfied: pyvis>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (2025.11.3)
# Requirement already satisfied: tomli-w>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (2.4.1)
# Requirement already satisfied: uv>=0.4.25 in /usr/local/lib/python3.12/dist-packages (from crewai==0.80.0) (0.11.23)
# Requirement already satisfied: aiohttp>=3.11.18 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (3.14.1)
# Requirement already satisfied: cryptography>=44.0.0 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (48.0.1)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (0.28.1)
# Requirement already satisfied: pydantic-core>=2.18.2 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (2.41.4)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (2.13.0)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (2.32.4)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (4.15.0)
# Requirement already satisfied: urllib3>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from auth0-python>=4.7.1->crewai==0.80.0) (2.5.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai==0.80.0) (0.49.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (2.0.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (1.81.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (3.11.9)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb>=0.4.24->crewai==0.80.0) (4.26.0)
# Requirement already satisfied: beautifulsoup4>=4.13.4 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (4.13.5)
# Requirement already satisfied: docker>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (7.1.0)
# Requirement already satisfied: lancedb>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (0.33.0)
# Requirement already satisfied: pypdf>=5.9.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (6.13.3)
# Requirement already satisfied: python-docx>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (1.2.0)
# Requirement already satisfied: pytube>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (15.0.0)
# Requirement already satisfied: stagehand>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (3.21.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (0.13.0)
# Requirement already satisfied: youtube-transcript-api>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from crewai-tools>=0.14.0->crewai==0.80.0) (1.2.4)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai==0.80.0) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai==0.80.0) (3.1.6)
# Requirement already satisfied: jiter<0.15,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai==0.80.0) (0.14.0)
# Collecting langchain-core<2.0.0,>=1.4.0 (from langchain>=0.2.16->crewai==0.80.0)
#   Downloading langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.4 in /usr/local/lib/python3.12/dist-packages (from langchain>=0.2.16->crewai==0.80.0) (1.2.4)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.44.22->crewai==0.80.0) (0.14.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.44.22->crewai==0.80.0) (8.7.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.13.3->crewai==0.80.0) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.13.3->crewai==0.80.0) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.13.3->crewai==0.80.0) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.80.0) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.80.0) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.80.0) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai==0.80.0) (5.29.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.22.0->crewai==0.80.0) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.2->crewai==0.80.0) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.2->crewai==0.80.0) (0.4.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from pyvis>=0.3.2->crewai==0.80.0) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from pyvis>=0.3.2->crewai==0.80.0) (4.1.2)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.12/dist-packages (from pyvis>=0.3.2->crewai==0.80.0) (3.6.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.18->auth0-python>=4.7.1->crewai==0.80.0) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.18->auth0-python>=4.7.1->crewai==0.80.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.18->auth0-python>=4.7.1->crewai==0.80.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.18->auth0-python>=4.7.1->crewai==0.80.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.18->auth0-python>=4.7.1->crewai==0.80.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.18->auth0-python>=4.7.1->crewai==0.80.0) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.18->auth0-python>=4.7.1->crewai==0.80.0) (1.24.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai==0.80.0) (3.18)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.13.4->crewai-tools>=0.14.0->crewai==0.80.0) (2.8.4)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb>=0.4.24->crewai==0.80.0) (25.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb>=0.4.24->crewai==0.80.0) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=44.0.0->auth0-python>=4.7.1->crewai==0.80.0) (2.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->auth0-python>=4.7.1->crewai==0.80.0) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.21.2->auth0-python>=4.7.1->crewai==0.80.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.21.2->auth0-python>=4.7.1->crewai==0.80.0) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm>=1.44.22->crewai==0.80.0) (4.1.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai==0.80.0) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb>=0.4.24->crewai==0.80.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb>=0.4.24->crewai==0.80.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb>=0.4.24->crewai==0.80.0) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai==0.80.0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai==0.80.0) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai==0.80.0) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai==0.80.0) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai==0.80.0) (0.10)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from lancedb>=0.5.4->crewai-tools>=0.14.0->crewai==0.80.0) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.12/dist-packages (from lancedb>=0.5.4->crewai-tools>=0.14.0->crewai==0.80.0) (18.1.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lancedb>=0.5.4->crewai-tools>=0.14.0->crewai==0.80.0) (0.8.6)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain>=0.2.16->crewai==0.80.0) (1.33)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.0->langchain>=0.2.16->crewai==0.80.0)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain>=0.2.16->crewai==0.80.0) (0.8.12)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain>=0.2.16->crewai==0.80.0) (0.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain>=0.2.16->crewai==0.80.0) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain>=0.2.16->crewai==0.80.0) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain>=0.2.16->crewai==0.80.0) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.4->langchain>=0.2.16->crewai==0.80.0) (3.7.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.4.24->crewai==0.80.0) (25.12.19)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx>=1.2.0->crewai-tools>=0.14.0->crewai==0.80.0) (6.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->auth0-python>=4.7.1->crewai==0.80.0) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb>=0.4.24->crewai==0.80.0) (4.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.13.2->chromadb>=0.4.24->crewai==0.80.0) (1.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb>=0.4.24->crewai==0.80.0) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb>=0.4.24->crewai==0.80.0) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai==0.80.0) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai==0.80.0) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai==0.80.0) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai==0.80.0) (15.0.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api>=1.2.2->crewai-tools>=0.14.0->crewai==0.80.0) (0.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=44.0.0->auth0-python>=4.7.1->crewai==0.80.0) (3.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.24->crewai==0.80.0) (3.29.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.24->crewai==0.80.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.24->crewai==0.80.0) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (0.8.7)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain>=0.2.16->crewai==0.80.0) (3.1.1)
# Requirement already satisfied: lance-namespace-urllib3-client==0.8.6 in /usr/local/lib/python3.12/dist-packages (from lance-namespace>=0.3.2->lancedb>=0.5.4->crewai-tools>=0.14.0->crewai==0.80.0) (0.8.6)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain>=0.2.16->crewai==0.80.0) (1.12.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain>=0.2.16->crewai==0.80.0) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain>=0.2.16->crewai==0.80.0) (0.25.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.4.24->crewai==0.80.0) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.80.0) (0.8.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb>=0.4.24->crewai==0.80.0) (3.3.1)
# Downloading langchain_core-1.4.8-py3-none-any.whl (557 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.4/557.4 kB 9.6 MB/s eta 0:00:00
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Installing collected packages: langchain-protocol, langchain-core
#   Attempting uninstall: langchain-protocol
#     Found existing installation: langchain-protocol 0.0.16
#     Uninstalling langchain-protocol-0.0.16:
#       Successfully uninstalled langchain-protocol-0.0.16
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.86
#     Uninstalling langchain-core-0.3.86:
#       Successfully uninstalled langchain-core-0.3.86
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-groq 0.2.1 requires langchain-core<0.4.0,>=0.3.15, but you have langchain-core 1.4.8 which is incompatible.
# Successfully installed langchain-core-1.4.8 langchain-protocol-0.0.18
# Requirement already satisfied: langchain-groq==0.2.1 in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from langchain-groq==0.2.1) (0.37.1)
# Collecting langchain-core<0.4.0,>=0.3.15 (from langchain-groq==0.2.1)
#   Using cached langchain_core-0.3.86-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.1) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.1) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.1) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.1) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.1) (4.15.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (0.8.12)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (6.0.3)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (0.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.2.1) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.1) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.1) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (2.32.4)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.15->langchain-groq==0.2.1) (2.5.0)
# Using cached langchain_core-0.3.86-py3-none-any.whl (461 kB)
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.8
#     Uninstalling langchain-core-1.4.8:
#       Successfully uninstalled langchain-core-1.4.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 1.3.6 requires langchain-core<2.0.0,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langgraph 1.2.4 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.86 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# Successfully installed langchain-core-0.3.86
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=4c1bd37ca97dd19abf3032860e3e8b1d8d218fbcf0c90ef82454e37d7947359d
#   Stored in directory: /root/.cache/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2

# %%
import crewai
import langchain_groq

print("CrewAI OK")
print("LangChain Groq OK")
# Out:
# CrewAI OK
# LangChain Groq OK

# %%
GROQ_API_KEY= "use your api key"

# %%
from crewai import LLM

llm = LLM(
    model="groq/llama-3.1-8b-instant",
    api_key=GROQ_API_KEY
)

# %%
from crewai import Agent, Task, Crew, Process

# %%
travel_researcher = Agent(
    role="Travel Researcher",
    goal="Find the best tourist attractions in Goa",
    backstory="You are an experienced travel expert.",
    llm=llm,
    verbose=True
)

# %%
research_task = Task(
    description="""
    Find 5 popular tourist places in Goa.
    Mention why tourists visit them.
    """,
    expected_output="List of 5 tourist attractions with explanations.",
    agent=travel_researcher
)

crew = Crew(
    agents=[travel_researcher],
    tasks=[research_task],
    process=Process.sequential,
    verbose=True
)

result = crew.kickoff()

print("\nFINAL RESULT:\n")
print(result)
# Out:
# # Agent: Travel Researcher
# ## Task:
#     Find 5 popular tourist places in Goa.
#     Mention why tourists visit them.
#
#
#
# # Agent: Travel Researcher
# ## Final Answer:
# This is the great list of popular tourist places to visit in Goa, along with explanations of why tourists visit them.
#
#
#
# FINAL RESULT:
#
# This is the great list of popular tourist places to visit in Goa, along with explanations of why tourists visit them.

# %%
from crewai import Agent, Task, Crew, Process, LLM

# LLM
llm = LLM(
    model="groq/llama-3.1-8b-instant",
    api_key=GROQ_API_KEY
)

# Agent 1
skill_analyzer = Agent(
    role="Skill Analyzer",
    goal="Analyze student skills and strengths",
    backstory="You are an expert in evaluating student abilities.",
    llm=llm,
    verbose=True
)

# Agent 2
career_advisor = Agent(
    role="Career Advisor",
    goal="Suggest suitable career paths",
    backstory="You help students choose careers.",
    llm=llm,
    verbose=True
)

# Agent 3
learning_mentor = Agent(
    role="Learning Mentor",
    goal="Create a learning roadmap",
    backstory="You design study plans and learning paths.",
    llm=llm,
    verbose=True
)

# Task 1
analysis_task = Task(
    description="""
    Student Details:

    Skills:
    - Python
    - SQL
    - Communication

    Interests:
    - Artificial Intelligence
    - Data Science

    Analyze strengths and weaknesses.
    """,
    expected_output="Detailed skill analysis.",
    agent=skill_analyzer
)

# Task 2
career_task = Task(
    description="""
    Based on the student's skills and interests,
    recommend suitable career options.
    """,
    expected_output="List of career recommendations.",
    agent=career_advisor
)

# Task 3
roadmap_task = Task(
    description="""
    Create a 6-month roadmap for the student
    to become job-ready.
    """,
    expected_output="Detailed learning roadmap.",
    agent=learning_mentor
)

crew = Crew(
    agents=[
        skill_analyzer,
        career_advisor,
        learning_mentor
    ],
    tasks=[
        analysis_task,
        career_task,
        roadmap_task
    ],
    process=Process.sequential,
    verbose=True
)

result = crew.kickoff()

print("\nFINAL RESULT:\n")
print(result)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: Skill Analyzer
# ## Task:
#     Student Details:
#
#     Skills:
#     - Python
#     - SQL
#     - Communication
#
#     Interests:
#     - Artificial Intelligence
#     - Data Science
#
#     Analyze strengths and weaknesses.
#
#
#
# # Agent: Skill Analyzer
# ## Final Answer:
# **Conclusion:**
# **Recommendations:**
# 1. Machine Learning and AI Coursework
# 2. Data Visualization Tool Familiarity
# 3. Interdisciplinary Collaboration
# 4. Project-based Learning
#
# **Detailed Skill Analysis:**
# Programming Skill (Python): 8/10
# Data Analysis and Modeling Skill: 8/10
# Communication Skill: 9/10
# Interest in AI and Data Science: 9/10
# Interdisciplinary Approach: 6/10
# Familiarity with Emerging Technologies: 6/10
# Data Visualization Skills: 7/10
#
#
# # Agent: Career Advisor
# ## Task:
#     Based on the student's skills and interests,
#     recommend suitable career options.
#
#
#
# # Agent: Career Advisor
# ## Final Answer:
# Based on the student's skills and interests, I recommend the following career options:
#
# 1. **Data Scientist**: As the student has a strong foundation in programming (Python), data analysis and modeling, and data visualization skills, they are well-suited for a career as a data scientist. This role involves working with large datasets, developing predictive models, and communicating insights to stakeholders, which leverages their strengths in AI and data science.
# 2. **Business Analyst - AI and Data Science**: This role requires the student to use their analytical and programming skills to identify business needs and develop solutions using AI and data science tools. Their strong communication skills will also be valuable in presenting insights and recommendations to stakeholders.
# 3. **UX Researcher**: With a strong interest in interdisciplinary collaboration and emerging technologies, the student could excel as a UX researcher. This role involves using data analysis and visualization skills to understand user behavior and develop innovative solutions.
# 4. **Quantitative Analyst**: The student's programming and data analysis skills make them a strong candidate for a career as a quantitative analyst. This role involves working with large datasets and developing predictive models to inform investment decisions or optimize business processes.
# 5. **Data Engineer**: As a data engineer, the student will focus on architecting and developing large-scale data systems, which leverages their programming and data analysis skills. This role involves working with emerging technologies, such as cloud computing and big data platforms.
# 6. **AI Researcher**: With a strong interest in AI and data science, the student could pursue a career as an AI researcher. This role involves developing and testing AI models, collaborating with interdisciplinary teams, and publishing research findings.
# 7. **Decision Analyst**: The student's strong analytical and programming skills make them a strong candidate for a career as a decision analyst. This role involves working with stakeholders to understand business needs and developing data-driven recommendations to inform business decisions.
# 8. **Computational Biologist**: With a strong interest in interdisciplinary collaboration and emerging technologies, the student could excel as a computational biologist. This role involves using programming and data analysis skills to analyze large biological datasets and develop new insights and models.
# 9. **Digital Product Manager**: As a digital product manager, the student will focus on developing data-driven strategies to inform product development and marketing initiatives. Their strong communication and analytical skills will be valuable in working with stakeholders and analyzing data to drive business decisions.
# 10. **Information Architect**: With a strong interest in interdisciplinary collaboration and emerging technologies, the student could pursue a career as an information architect. This role involves designing and implementing information systems that meet business needs, leveraging their data analysis and visualization skills.
#
# These career options align with the student's strengths and passions, and offer a range of opportunities for growth and development in the fields of AI, data science, and emerging technologies.
#
#
# # Agent: Learning Mentor
# ## Task:
#     Create a 6-month roadmap for the student
#     to become job-ready.
#
#
#
# # Agent: Learning Mentor
# ## Final Answer:
# **Learning Roadmap: 6-Month Plan to Become Job-Ready**
#
# **Month 1: Career Research and Skill Assessment (Weeks 1-4)**
#
# 1. **Week 1-2**: Research and explore the top 3 career options identified for the student (Data Scientist, Business Analyst - AI and Data Science, and UX Researcher). Read industry reports, articles, and blogs to get an in-depth understanding of each role.
# 2. **Week 3-4**: Conduct a skill assessment to identify the student's strengths and weaknesses in programming, data analysis and modeling, and data visualization. Create a skills matrix to track progress.
#
# **Month 2: Foundational Skill Development (Weeks 5-8)**
#
# 1. **Week 5-6**: Focus on developing programming skills, including data structures, algorithms, and software design patterns. Complete online courses and coding exercises to improve proficiency in languages like Python, R, or SQL.
# 2. **Week 7-8**: Enhance data analysis and modeling skills, including statistical modeling, machine learning, and data visualization using libraries like Pandas, NumPy, and Matplotlib.
#
# **Month 3: Specialized Skill Development (Weeks 9-12)**
#
# 1. **Week 9-10**: Develop specialized skills for the chosen career path, such as:
# 	* Data Scientist: Deep learning, natural language processing, or computer vision.
# 	* Business Analyst - AI and Data Science: Business acumen, data storytelling, or cloud computing.
# 	* UX Researcher: Human-centered design, user research methods, or empathy mapping.
# 2. **Week 11-12**: Practice working with real-world datasets and project applications.
#
# **Month 4: Project-Based Learning (Weeks 13-16)**
#
# 1. **Week 13-14**: Work on a project that applies the skills learned in the previous months, such as:
# 	* Data Science: Develop a predictive model using a public dataset or a real-world business problem.
# 	* Business Analyst - AI and Data Science: Create a business case study or a proposal for implementing AI and data science solutions.
# 	* UX Researcher: Conduct user research and design a product solution.
# 2. **Week 15-16**: Refine and iterate on the project, incorporating feedback from industry professionals or mentors.
#
# **Month 5: Networking and Interview Preparation (Weeks 17-20)**
#
# 1. **Week 17-18**: Attend industry events, conferences, or meetups to network with professionals in the field.
# 2. **Week 19-20**: Prepare for job interviews by practicing common interview questions, creating a portfolio or LinkedIn profile, and learning about the companies and roles.
#
# **Month 6: Job Application and Placement (Weeks 21-24)**
#
# 1. **Week 21-22**: Apply to job openings that match the student's career goals and skills.
# 2. **Week 23-24**: Participate in the hiring process, including coding challenges, skill assessments, or in-person interviews.
#
# **Continuous Monitoring and Evaluation**
#
# Throughout the 6-month period, the student will be monitored and evaluated based on progress, skill development, and project completion. The learning roadmap will be adjusted accordingly to ensure the student meets the job-ready criteria.
#
# By following this learning roadmap, the student will gain the necessary skills, knowledge, and industry connections to become job-ready and succeed in their chosen career path.
#
#
#
# FINAL RESULT:
#
# **Learning Roadmap: 6-Month Plan to Become Job-Ready**
#
# **Month 1: Career Research and Skill Assessment (Weeks 1-4)**
#
# 1. **Week 1-2**: Research and explore the top 3 career options identified for the student (Data Scientist, Business Analyst - AI and Data Science, and UX Researcher). Read industry reports, articles, and blogs to get an in-depth understanding of each role.
# 2. **Week 3-4**: Conduct a skill assessment to identify the student's strengths and weaknesses in programming, data analysis and modeling, and data visualization. Create a skills matrix to track progress.
#
# **Month 2: Foundational Skill Development (Weeks 5-8)**
#
# 1. **Week 5-6**: Focus on developing programming skills, including data structures, algorithms, and software design patterns. Complete online courses and coding exercises to improve proficiency in languages like Python, R, or SQL.
# 2. **Week 7-8**: Enhance data analysis and modeling skills, including statistical modeling, machine learning, and data visualization using libraries like Pandas, NumPy, and Matplotlib.
#
# **Month 3: Specialized Skill Development (Weeks 9-12)**
#
# 1. **Week 9-10**: Develop specialized skills for the chosen career path, such as:
# 	* Data Scientist: Deep learning, natural language processing, or computer vision.
# 	* Business Analyst - AI and Data Science: Business acumen, data storytelling, or cloud computing.
# 	* UX Researcher: Human-centered design, user research methods, or empathy mapping.
# 2. **Week 11-12**: Practice working with real-world datasets and project applications.
#
# **Month 4: Project-Based Learning (Weeks 13-16)**
#
# 1. **Week 13-14**: Work on a project that applies the skills learned in the previous months, such as:
# 	* Data Science: Develop a predictive model using a public dataset or a real-world business problem.
# 	* Business Analyst - AI and Data Science: Create a business case study or a proposal for implementing AI and data science solutions.
# 	* UX Researcher: Conduct user research and design a product solution.
# 2. **Week 15-16**: Refine and iterate on the project, incorporating feedback from industry professionals or mentors.
#
# **Month 5: Networking and Interview Preparation (Weeks 17-20)**
#
# 1. **Week 17-18**: Attend industry events, conferences, or meetups to network with professionals in the field.
# 2. **Week 19-20**: Prepare for job interviews by practicing common interview questions, creating a portfolio or LinkedIn profile, and learning about the companies and roles.
#
# **Month 6: Job Application and Placement (Weeks 21-24)**
#
# 1. **Week 21-22**: Apply to job openings that match the student's career goals and skills.
# 2. **Week 23-24**: Participate in the hiring process, including coding challenges, skill assessments, or in-person interviews.
#
# **Continuous Monitoring and Evaluation**
#
# Throughout the 6-month period, the student will be monitored and evaluated based on progress, skill development, and project completion. The learning roadmap will be adjusted accordingly to ensure the student meets the job-ready criteria.
#
# By following this learning roadmap, the student will gain the necessary skills, knowledge, and industry connections to become job-ready and succeed in their chosen career path.

# %% [markdown]
# ### Generating PDF Output
#
# Now, let's use the `fpdf` library to generate a PDF file from the `FINAL RESULT` of the CrewAI execution. This will create a PDF document named `crewai_results.pdf` in your current directory.

# %%
from fpdf import FPDF

pdf = FPDF()
pdf.add_page()
pdf.set_font('Arial', 'B', 12)
pdf.multi_cell(0, 10, 'CrewAI Execution Results:\n\n')
pdf.set_font('Arial', '', 10)

# The 'result' variable from the previous cell holds the final output
pdf.multi_cell(0, 5, str(result))

pdf_output_filename = 'crewai_results.pdf'
pdf.output(pdf_output_filename)

print(f'PDF generated successfully: {pdf_output_filename}')
# Out:
# PDF generated successfully: crewai_results.pdf
